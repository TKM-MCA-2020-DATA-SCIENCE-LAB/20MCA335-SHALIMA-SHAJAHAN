# %% [markdown]
# EXTERNAL LAB EXAM

# %% [markdown]
# Program to implement decision tree using any standard dataset available in the public domain and find accuracy of the algorithm

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score,classification_report

# %%
from sklearn.datasets import load_iris

# %%
df=load_iris()

# %%
df

# %%
x=df.data

# %%
df.data.shape
# Out:
# (150, 4)

# %%
df.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
y=df.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=45)

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred=dtree.predict(x_test)

# %%
print("accuracy on train data using gini:",accuracy_score(y_train,dtree.predict(x_train)))
# Out:
# accuracy on train data using gini: 1.0

# %%
print("accuracy on test dataset using gini:",accuracy_score(y_test,pred))
# Out:
# accuracy on test dataset using gini: 0.9555555555555556

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       0.87      1.00      0.93        13
#            2       1.00      0.87      0.93        15
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
from sklearn.tree import export_graphviz
from six import StringIO 
from IPython.display import Image 
import pydotplus
dot_data = StringIO()
export_graphviz(dtree, filled = True, rounded=True,  out_file=dot_data,feature_names = df.feature_names, class_names = df.target_names)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
